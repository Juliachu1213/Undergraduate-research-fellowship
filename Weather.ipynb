# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
from glob import glob
import os
import numpy as np
df = pd.DataFrame()


# 讀取第一個CSV檔案幷包含表頭

allfiles = glob('/Users/julia/Desktop/科技部大專生計畫/宜蘭天氣資料/2021預測天氣/*.csv')
allfiles=sorted(allfiles)

# %%
allfiles
# Out:
# ['/Users/julia/Desktop/科技部大專生計畫/宜蘭天氣資料/2021預測天氣/2021_三星測站.csv',
#  '/Users/julia/Desktop/科技部大專生計畫/宜蘭天氣資料/2021預測天氣/2021_五結測站.csv',
#  '/Users/julia/Desktop/科技部大專生計畫/宜蘭天氣資料/2021預測天氣/2021_大礁溪測站.csv',
#  '/Users/julia/Desktop/科技部大專生計畫/宜蘭天氣資料/2021預測天氣/2021_礁溪測站.csv']

# %%
df_all = pd.DataFrame()
for file in allfiles:
    data=pd.read_csv(file, dtype={'Rank': str})
    data=data.iloc[0:]
    df_all=pd.concat([df_all,data],axis=0)

# %%
df_all.reset_index(drop=True)
# Out:
#        Unnamed: 0          日期  測站  觀測時間    測站氣壓 海平面氣壓    氣溫 露點溫度  相對溼度   風速  \
# 0               0  2021-01-01  三星   1.0  1016.3   ...   9.3  ...  72.0  2.7
# 1               1  2021-01-01  三星   2.0  1016.1   ...   9.6  ...  68.0  2.3
# 2               2  2021-01-01  三星   3.0  1015.7   ...  10.1  ...  64.0  1.9
# 3               3  2021-01-01  三星   4.0  1015.7   ...  10.0  ...  67.0  2.4
# 4               4  2021-01-01  三星   5.0  1015.6   ...   9.5  ...  76.0  2.3
# ...           ...         ...  ..   ...     ...   ...   ...  ...   ...  ...
# 14491        3619  2021-05-31  礁溪  20.0  1005.8   ...  23.5  ...  99.0  0.1
# 14492        3620  2021-05-31  礁溪  21.0  1006.4   ...  23.4  ...  99.0  0.1
# 14493        3621  2021-05-31  礁溪  22.0  1006.2   ...  23.3  ...  99.0  0.0
# 14494        3622  2021-05-31  礁溪  23.0  1006.2   ...  23.1  ...  99.0  0.1
# 14495        3623  2021-05-31  礁溪  24.0  1006.0   ...  22.9  ...  98.0  0.4
#
# ...

# %%
df_all = df_all.drop(['Unnamed: 0'],axis=1)

# %%
df_all =df_all.replace("...",np.nan)

# %%
df_all = df_all.replace("T",0)

# %%
pd.DataFrame((df_all.iloc[:,3:].isnull().sum(axis = 0)/df_all.shape[0]),columns=['缺失值佔比']).iloc[8:]
# Out:
#            缺失值佔比
# 最大陣風風向  1.000000
# 降水量     0.005243
# 降水時數    1.000000
# 日照時數    1.000000
# 全天空日射量  1.000000
# 能見度     1.000000
# 紫外線指數   1.000000
# 總雲量     1.000000

# %%
df_all.columns
# Out:
# Index(['日期', '測站', '觀測時間', '測站氣壓', '海平面氣壓', '氣溫', '露點溫度', '相對溼度', '風速', '風向',
#        '最大陣風', '最大陣風風向', '降水量', '降水時數', '日照時數', '全天空日射量', '能見度', '紫外線指數',
#        '總雲量'],
#       dtype='object')

# %%
df_all_1 = df_all[['日期', '測站', '觀測時間', '測站氣壓', '氣溫', '相對溼度', '風速', '風向',
       '降水量']]

# %%
# Out:
# /Users/julia/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 28204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/julia/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 31449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/julia/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 27683 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/julia/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22739 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/julia/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 28204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
df_all_1.to_csv('/Users/julia/Desktop/科技部大專生計畫/宜蘭天氣資料/2021天氣資料.csv')

# %%
df = pd.read_csv('/Users/julia/Desktop/科技部大專生計畫/宜蘭天氣資料/yl_weather.csv')
# Out:
# /Users/julia/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3343: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.Station.unique()
# Out:
# array(['蘇澳', '宜蘭', '雙連埤', '礁溪', '玉蘭', '太平山', '龜山島', '東澳', '南澳', '五結',
#        '頭城', '大礁溪', '三星', '內城', '冬山', '羅東', '鶯子嶺', '大福', '坪林石牌', '員山',
#        '牛鬥', '寒溪', '新寮', '烏石鼻', '東澳嶺', '觀音海岸', '北關', '南山', '翠峰湖', '土場',
#        '鴛鴦湖', '多加屯', '白嶺', '西德山', '西帽山', '樟樹山', '桃源谷', '思源'], dtype=object)

# %%
df2 = df[(df['Date'] < '2021-01-01')&(df['Date']>= '2020-01-01')]

# %%
df2 = df2[['Date','Station','Station_no','City','Hour','StnPres','Temperature','RH','WS','WD','Precp']]

# %%
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#               Date Station Station_no City  Hour  StnPres  Temperature    RH  \
# 0       2020-01-01      蘇澳     467060  宜蘭縣     1   1025.6         14.9  86.0
# 1       2020-01-01      蘇澳     467060  宜蘭縣     2   1025.1         15.1  86.0
# 2       2020-01-01      蘇澳     467060  宜蘭縣     3   1024.8         15.3  85.0
# 3       2020-01-01      蘇澳     467060  宜蘭縣     4   1024.5         15.5  84.0
# 4       2020-01-01      蘇澳     467060  宜蘭縣     5   1025.0         15.1  92.0
# ...            ...     ...        ...  ...   ...      ...          ...   ...
# 233275  2020-12-31      北關     C1U880  宜蘭縣    20      NaN          NaN   NaN
# 233276  2020-12-31      北關     C1U880  宜蘭縣    21      NaN          NaN   NaN
# 233277  2020-12-31      北關     C1U880  宜蘭縣    22      NaN          NaN   NaN
# 233278  2020-12-31      北關     C1U880  宜蘭縣    23      NaN          NaN   NaN
# 233279  2020-12-31      北關     C1U880  宜蘭縣    24      NaN          NaN   NaN
#
#          WS     WD  Precp
# ...

# %%
df2.isnull().sum()
# Out:
# Date               0
# Station            0
# Station_no         0
# City               0
# Hour               0
# StnPres        60965
# Temperature    60771
# RH             68583
# WS             61390
# WD             61465
# Precp           1414
# dtype: int64

# %%
df2.to_csv('/Users/julia/Desktop/科技部大專生計畫/宜蘭天氣資料/天氣資料.csv')

# %%
df2.loc[df2['Station']=='寒溪']  #梅花湖
# Out:
#               Date Station Station_no City  Hour  StnPres  Temperature  RH  \
# 504     2020-01-01      寒溪     C1U670  宜蘭縣     1      NaN          NaN NaN
# 505     2020-01-01      寒溪     C1U670  宜蘭縣     2      NaN          NaN NaN
# 506     2020-01-01      寒溪     C1U670  宜蘭縣     3      NaN          NaN NaN
# 507     2020-01-01      寒溪     C1U670  宜蘭縣     4      NaN          NaN NaN
# 508     2020-01-01      寒溪     C1U670  宜蘭縣     5      NaN          NaN NaN
# ...            ...     ...        ...  ...   ...      ...          ...  ..
# 233155  2020-12-31      寒溪     C1U670  宜蘭縣    20      NaN          NaN NaN
# 233156  2020-12-31      寒溪     C1U670  宜蘭縣    21      NaN          NaN NaN
# 233157  2020-12-31      寒溪     C1U670  宜蘭縣    22      NaN          NaN NaN
# 233158  2020-12-31      寒溪     C1U670  宜蘭縣    23      NaN          NaN NaN
# 233159  2020-12-31      寒溪     C1U670  宜蘭縣    24      NaN          NaN NaN
#
#         WS  WD  Precp
# 504    NaN NaN    0.0
# ...

# %%
df2.loc[df2['Station']=='五結'] #宜蘭傳統藝術中心 冬山河親水公園
# Out:
#               Date Station Station_no City  Hour  StnPres  Temperature    RH  \
# 216     2020-01-01      五結     C0U780  宜蘭縣     1   1028.4         13.3  99.0
# 217     2020-01-01      五結     C0U780  宜蘭縣     2   1028.0         13.3  99.0
# 218     2020-01-01      五結     C0U780  宜蘭縣     3   1027.6         13.4  99.0
# 219     2020-01-01      五結     C0U780  宜蘭縣     4   1027.5         13.5  99.0
# 220     2020-01-01      五結     C0U780  宜蘭縣     5   1027.9         13.2  99.0
# ...            ...     ...        ...  ...   ...      ...          ...   ...
# 232867  2020-12-31      五結     C0U780  宜蘭縣    20   1029.3          9.7  79.0
# 232868  2020-12-31      五結     C0U780  宜蘭縣    21   1029.4          9.8  80.0
# 232869  2020-12-31      五結     C0U780  宜蘭縣    22   1029.0         10.0  79.0
# 232870  2020-12-31      五結     C0U780  宜蘭縣    23   1028.9          9.8  84.0
# 232871  2020-12-31      五結     C0U780  宜蘭縣    24   1028.8          9.6  87.0
#
#          WS     WD  Precp
# ...

# %%
df2.loc[df2['Station']=='頭城']  #蘭陽博物館 外澳遊憩區
# Out:
#               Date Station Station_no City  Hour  StnPres  Temperature    RH  \
# 240     2020-01-01      頭城     C0U860  宜蘭縣     1   1029.3         14.0  94.0
# 241     2020-01-01      頭城     C0U860  宜蘭縣     2   1028.8         13.9  94.0
# 242     2020-01-01      頭城     C0U860  宜蘭縣     3   1028.4         14.2  94.0
# 243     2020-01-01      頭城     C0U860  宜蘭縣     4   1028.4         14.5  94.0
# 244     2020-01-01      頭城     C0U860  宜蘭縣     5   1028.8         14.2  95.0
# ...            ...     ...        ...  ...   ...      ...          ...   ...
# 232891  2020-12-31      頭城     C0U860  宜蘭縣    20   1029.8         10.6  64.0
# 232892  2020-12-31      頭城     C0U860  宜蘭縣    21   1029.7         10.9  64.0
# 232893  2020-12-31      頭城     C0U860  宜蘭縣    22   1029.5         10.6  68.0
# 232894  2020-12-31      頭城     C0U860  宜蘭縣    23   1029.2         10.7  64.0
# 232895  2020-12-31      頭城     C0U860  宜蘭縣    24   1028.9         10.9  63.0
#
#          WS     WD  Precp
# ...

# %%
df2.loc[df2['Station']=='三星'] #清水地熱公園
# Out:
#               Date Station Station_no City  Hour  StnPres  Temperature    RH  \
# 288     2020-01-01      三星     C0U890  宜蘭縣     1   1017.3         12.6  99.0
# 289     2020-01-01      三星     C0U890  宜蘭縣     2   1016.8         12.9  99.0
# 290     2020-01-01      三星     C0U890  宜蘭縣     3   1016.7         13.0  99.0
# 291     2020-01-01      三星     C0U890  宜蘭縣     4   1016.3         13.0  99.0
# 292     2020-01-01      三星     C0U890  宜蘭縣     5   1016.6         13.4  99.0
# ...            ...     ...        ...  ...   ...      ...          ...   ...
# 232939  2020-12-31      三星     C0U890  宜蘭縣    20   1017.2          9.1  70.0
# 232940  2020-12-31      三星     C0U890  宜蘭縣    21   1017.3          9.1  70.0
# 232941  2020-12-31      三星     C0U890  宜蘭縣    22   1016.9          9.5  66.0
# 232942  2020-12-31      三星     C0U890  宜蘭縣    23   1016.9          8.6  79.0
# 232943  2020-12-31      三星     C0U890  宜蘭縣    24   1016.6          8.9  73.0
#
#          WS     WD  Precp
# ...

# %%
df2.loc[df2['Station']=='礁溪'] #五峰旗   *湯圍溝溫泉公園
# Out:
#               Date Station Station_no City  Hour  StnPres  Temperature    RH  \
# 72      2020-01-01      礁溪     C0U600  宜蘭縣     1   1027.8         13.7  99.0
# 73      2020-01-01      礁溪     C0U600  宜蘭縣     2   1027.4         13.8  99.0
# 74      2020-01-01      礁溪     C0U600  宜蘭縣     3   1027.1         13.8  99.0
# 75      2020-01-01      礁溪     C0U600  宜蘭縣     4   1027.1         14.0  99.0
# 76      2020-01-01      礁溪     C0U600  宜蘭縣     5   1027.3         13.8  99.0
# ...            ...     ...        ...  ...   ...      ...          ...   ...
# 232723  2020-12-31      礁溪     C0U600  宜蘭縣    20   1027.9         10.3  68.0
# 232724  2020-12-31      礁溪     C0U600  宜蘭縣    21   1028.0         10.0  78.0
# 232725  2020-12-31      礁溪     C0U600  宜蘭縣    22   1027.7          9.6  87.0
# 232726  2020-12-31      礁溪     C0U600  宜蘭縣    23   1027.5          9.6  88.0
# 232727  2020-12-31      礁溪     C0U600  宜蘭縣    24   1027.3          9.6  89.0
#
#          WS     WD  Precp
# ...

# %%
df2.loc[df2['Station']=='大礁溪'] #龍潭湖
# Out:
#               Date Station Station_no City  Hour  StnPres  Temperature     RH  \
# 264     2020-01-01     大礁溪     C0U870  宜蘭縣     1    974.7         10.5  100.0
# 265     2020-01-01     大礁溪     C0U870  宜蘭縣     2    974.3         10.7  100.0
# 266     2020-01-01     大礁溪     C0U870  宜蘭縣     3    974.1         10.7  100.0
# 267     2020-01-01     大礁溪     C0U870  宜蘭縣     4    973.9         10.9  100.0
# 268     2020-01-01     大礁溪     C0U870  宜蘭縣     5    974.3         11.0  100.0
# ...            ...     ...        ...  ...   ...      ...          ...    ...
# 232915  2020-12-31     大礁溪     C0U870  宜蘭縣    20    974.0          6.2   80.0
# 232916  2020-12-31     大礁溪     C0U870  宜蘭縣    21    974.1          6.0   85.0
# 232917  2020-12-31     大礁溪     C0U870  宜蘭縣    22    973.9          6.1   82.0
# 232918  2020-12-31     大礁溪     C0U870  宜蘭縣    23    973.8          6.0   85.0
# 232919  2020-12-31     大礁溪     C0U870  宜蘭縣    24    973.6          6.3   80.0
#
#          WS     WD  Precp
# ...

# %%
df2.loc[df2['Station']=='太平山'] #太平山森林
# Out:
#               Date Station Station_no City  Hour  StnPres  Temperature     RH  \
# 120     2020-01-01     太平山     C0U710  宜蘭縣     1    814.8          2.6  100.0
# 121     2020-01-01     太平山     C0U710  宜蘭縣     2    814.4          2.4   99.0
# 122     2020-01-01     太平山     C0U710  宜蘭縣     3    814.2          2.7   99.0
# 123     2020-01-01     太平山     C0U710  宜蘭縣     4    814.2          2.5   99.0
# 124     2020-01-01     太平山     C0U710  宜蘭縣     5    814.5          4.5   99.0
# ...            ...     ...        ...  ...   ...      ...          ...    ...
# 232771  2020-12-31     太平山     C0U710  宜蘭縣    20    809.9         -3.7  100.0
# 232772  2020-12-31     太平山     C0U710  宜蘭縣    21    810.1         -3.7  100.0
# 232773  2020-12-31     太平山     C0U710  宜蘭縣    22    809.9         -3.7  100.0
# 232774  2020-12-31     太平山     C0U710  宜蘭縣    23    809.7         -3.6  100.0
# 232775  2020-12-31     太平山     C0U710  宜蘭縣    24    809.7         -3.6  100.0
#
#          WS     WD  Precp
# ...
